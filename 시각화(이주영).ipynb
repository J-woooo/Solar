# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv('./data/부산/부산복합자재창고_발전량.csv', encoding='euc-kr', parse_dates=['년월일'])
df.shape
# Out:
# (2769, 10)

# %%
#df = df.fillna(0)
df.isnull().sum()
# Out:
# 년월일                 0
# 총량(kw)              0
# 최저기온(°C)            0
# 최고기온(°C)            0
# 일강수량(mm)         1870
# 평균 풍속(m/s)          1
# 평균 상대습도(%)          0
# 가조시간(hr)            0
# 합계 일사량(MJ/m2)      73
# 평균 전운량(1/10)        0
# dtype: int64

# %%
df.head()
df.tail()
# Out:
#          년월일  총량(kw)  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 0 2013-01-01  507.36      -2.8       8.0       NaN         3.1        48.5
# 1 2013-01-02  625.20      -5.9       3.6       NaN         4.0        40.9
# 2 2013-01-03  656.88      -7.7      -1.0       NaN         3.9        26.3
# 3 2013-01-04  701.28      -8.1       2.8       NaN         3.7        24.6
# 4 2013-01-05  686.40      -3.8       3.4       NaN         3.4        26.4
#
#    가조시간(hr)  합계 일사량(MJ/m2)  평균 전운량(1/10)
# 0       9.9           8.99           3.4
# 1       9.9          10.30           1.5
# 2       9.9          10.77           2.8
# 3       9.9          11.36           0.3
# 4       9.9          11.14           0.8
#             년월일  총량(kw)  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 2764 2020-07-27  207.36      21.5      24.7      32.1         1.8        94.4
# 2765 2020-07-28  163.44      21.5      22.8      46.5         1.5        96.6
# ...

# %%
df['일강수량(mm)'].describe()
# Out:
# count    899.000000
# mean      13.320690
# std       25.088904
# min        0.000000
# 25%        0.300000
# 50%        2.600000
# 75%       14.550000
# max      264.100000
# Name: 일강수량(mm), dtype: float64

# %%
df['합계 일사량(MJ/m2)'].describe()
# Out:
# count    2696.000000
# mean       14.553190
# std         7.233134
# min         0.170000
# 25%         9.547500
# 50%        13.860000
# 75%        20.207500
# max        34.680000
# Name: 합계 일사량(MJ/m2), dtype: float64

# %%
import os

df_test1 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]
df_test1 = df_test1.loc[0:30, :]
#x_values = df[['년월일']].loc[0:364, :]
#y_values1 = df[['총량(kw)']].loc[0:364, :]
#y_values2 = df[['합계 일사량(MJ/m2)']].loc[0:364, :]
#x_values.head()

plt.rc('font', family='Malgun Gothic')
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

#ax.plot(df_test1['년월일'], df_test1['총량(kw)'], label = '총량')
ax.plot(df_test1['년월일'], df_test1['최저기온(°C)'], label = '최저기온(°C)')
ax.plot(df_test1['년월일'], df_test1['최고기온(°C)'], label = '최고기온(°C)')
ax.plot(df_test1['년월일'], df_test1['일강수량(mm)'], label = '일강수량(mm)')
ax.plot(df_test1['년월일'], df_test1['평균 풍속(m/s)'], label = '평균 풍속(m/s)')
ax.plot(df_test1['년월일'], df_test1['평균 상대습도(%)'], label = '평균 상대습도(%)')
ax.plot(df_test1['년월일'], df_test1['가조시간(hr)'], label = '가조시간(hr)')
ax.plot(df_test1['년월일'], df_test1['합계 일사량(MJ/m2)'], label = '합계 일사량(MJ/m2)')
ax.plot(df_test1['년월일'], df_test1['평균 전운량(1/10)'], label = '평균 전운량(1/10)')

ax.set_title("13년도 1월 일별 추이")
ax.set_xlabel("년월")
ax.set_ylabel("변화량")

ax.legend()
plt.show()
# Out:
# Text(0.5, 1.0, '13년도 1월 일별 추이')
# Text(0.5, 0, '년월')
# Text(0, 0.5, '변화량')

# %%
#df = df.fillna(0)

df_test1 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]
df_test1 = df_test1.loc[0:364, :] #13년도
#df_test1 = df_test1.loc[365:729, :] #14년도
#df_test1 = df_test1.loc[730:1094, :] #15년도
#df_test1 = df_test1.loc[1095:1460, :] #16년도
#df_test1 = df_test1.loc[1461:1825, :] #17년도
#df_test1 = df_test1.loc[1826:2190, :] #18년도
#df_test1 = df_test1.loc[2191:2555, :] #19년도
#df_test1 = df_test1.loc[2556:2768, :] #20년도

m = df_test1['년월일'].dt.month
result = df_test1.groupby(m).mean()
result.index = pd.date_range('2013-01-01', periods = 12, freq='MS').strftime('%Y %m')
#result = pd.date_range('2013-01-01', periods = 91, freq = 'MS')

plt.rc('font', family='Malgun Gothic')
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

#ax.plot(df_test1['년월일'], df_test1[['총량(kw)'].mean(), label = '총량')
ax.plot(result.index, result['최고기온(°C)'], label = '최고기온(°C)')
ax.plot(result.index, result['최저기온(°C)'], label = '최저기온(°C)')
ax.plot(result.index, result['일강수량(mm)'], label = '일강수량(mm)')
ax.plot(result.index, result['평균 풍속(m/s)'], label = '평균 풍속(m/s)')
ax.plot(result.index, result['평균 상대습도(%)'], label = '평균 상대습도(%)')
ax.plot(result.index, result['가조시간(hr)'], label = '가조시간(hr)')
ax.plot(result.index, result['합계 일사량(MJ/m2)'], label = '합계 일사량(MJ/m2)')
ax.plot(result.index, result['평균 전운량(1/10)'], label = '평균 전운량(1/10)')

ax.set_title("13년도 월별 추이")
ax.set_xlabel("월")
ax.set_ylabel("변화량")

ax.legend()
plt.show()
# Out:
# Text(0.5, 1.0, '13년도 월별 추이')
# Text(0.5, 0, '월')
# Text(0, 0.5, '변화량')

# %%
#df = df.fillna(0)

df_test1 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]

y = df_test1['년월일'].dt.year
result = df_test1.groupby(y).mean()
result.index = pd.date_range('2013-01-01', periods = 8, freq='AS-JAN').strftime('%Y %m')
#result = pd.date_range('2013-01-01', periods = 91, freq = 'MS')

plt.rc('font', family='Malgun Gothic')
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

#ax.plot(df_test1['년월일'], df_test1[['총량(kw)'].mean(), label = '총량')
ax.plot(result.index, result['최고기온(°C)'], label = '최고기온(°C)')
ax.plot(result.index, result['최저기온(°C)'], label = '최저기온(°C)')
ax.plot(result.index, result['일강수량(mm)'], label = '일강수량(mm)')
ax.plot(result.index, result['평균 풍속(m/s)'], label = '평균 풍속(m/s)')
ax.plot(result.index, result['평균 상대습도(%)'], label = '평균 상대습도(%)')
ax.plot(result.index, result['가조시간(hr)'], label = '가조시간(hr)')
ax.plot(result.index, result['합계 일사량(MJ/m2)'], label = '합계 일사량(MJ/m2)')
ax.plot(result.index, result['평균 전운량(1/10)'], label = '평균 전운량(1/10)')

ax.set_title("연도별 추이")
ax.set_xlabel("년")
ax.set_ylabel("변화량")

ax.legend()
plt.show()
# Out:
# Text(0.5, 1.0, '연도별 추이')
# Text(0.5, 0, '년')
# Text(0, 0.5, '변화량')

# %%
#df = df.fillna(0)

df_test1 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]
df_test2 = df_test1.loc[0:364, :] #13년도
df_test3 = df_test1.loc[365:729, :] #14년도
df_test4 = df_test1.loc[730:1094, :] #15년도
df_test5 = df_test1.loc[1095:1460, :] #16년도
df_test6 = df_test1.loc[1461:1825, :] #17년도
df_test7 = df_test1.loc[1826:2190, :] #18년도
df_test8 = df_test1.loc[2191:2555, :] #19년도
#df_test9 = df_test1.loc[2556:2768, :] #20년도

m2 = df_test2['년월일'].dt.month
result2 = df_test2.groupby(m2).mean()
result2.index = pd.date_range('2013-01-01', periods = 12, freq='MS').strftime('%B')

m3 = df_test3['년월일'].dt.month
result3 = df_test3.groupby(m3).mean()
result3.index = pd.date_range('2014-01-01', periods = 12, freq='MS').strftime('%B')

m4 = df_test4['년월일'].dt.month
result4 = df_test4.groupby(m4).mean()
result4.index = pd.date_range('2015-01-01', periods = 12, freq='MS').strftime('%B')

m5 = df_test5['년월일'].dt.month
result5 = df_test5.groupby(m5).mean()
result5.index = pd.date_range('2016-01-01', periods = 12, freq='MS').strftime('%B')

m6 = df_test6['년월일'].dt.month
result6 = df_test6.groupby(m6).mean()
result6.index = pd.date_range('2017-01-01', periods = 12, freq='MS').strftime('%B')

m7 = df_test7['년월일'].dt.month
result7 = df_test7.groupby(m7).mean()
result7.index = pd.date_range('2018-01-01', periods = 12, freq='MS').strftime('%B')

m8 = df_test8['년월일'].dt.month
result8 = df_test8.groupby(m8).mean()
result8.index = pd.date_range('2019-01-01', periods = 12, freq='MS').strftime('%B')

plt.rc('font', family='Malgun Gothic')
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

ax.plot(result2.index, result2['총량(kw)'], label = '13년도 총량(kw)')
ax.plot(result3.index, result3['총량(kw)'], label = '14년도 총량(kw)')
ax.plot(result4.index, result4['총량(kw)'], label = '15년도 총량(kw)')
ax.plot(result5.index, result5['총량(kw)'], label = '16년도 총량(kw)')
ax.plot(result6.index, result6['총량(kw)'], label = '17년도 총량(kw)')
ax.plot(result7.index, result7['총량(kw)'], label = '18년도 총량(kw)')
ax.plot(result8.index, result8['총량(kw)'], label = '19년도 총량(kw)')

ax.set_title("연도별 발전량")
ax.set_xlabel("월")
ax.set_ylabel("변화량")

ax.legend()
plt.show()
# Out:
# Text(0.5, 1.0, '연도별 발전량')
# Text(0.5, 0, '월')
# Text(0, 0.5, '변화량')

# %%
def compute_pos(xticks, width, i, models):
    index = np.arange(len(xticks))
    n = len(models)
    correction = i-0.5*(n-1)
    return index + width*correction

def present_height(ax, bar):
    for rect in bar:
        height = rect.get_height()
        posx = rect.get_x()+rect.get_width()*0.5
        posy = height*1.01
        ax.text(posx, posy, '%.3f' % height, rotation=90, ha='center', va='bottom')

#df = df.fillna(0)

df_test1 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]
df_test2 = df_test1.loc[0:364, :] #13년도
df_test3 = df_test1.loc[365:729, :] #14년도
df_test4 = df_test1.loc[730:1094, :] #15년도
df_test5 = df_test1.loc[1095:1460, :] #16년도
df_test6 = df_test1.loc[1461:1825, :] #17년도
df_test7 = df_test1.loc[1826:2190, :] #18년도
df_test8 = df_test1.loc[2191:2555, :] #19년도
#df_test9 = df_test1.loc[2556:2768, :] #20년도

m2 = df_test2['년월일'].dt.month
result2 = df_test2.groupby(m2).mean()
result2.index = pd.date_range('2013-01-01', periods = 12, freq='MS').strftime('%B')
r2 = result2['총량(kw)'].values.tolist()
r2 = list(map(int, r2))

m3 = df_test3['년월일'].dt.month
result3 = df_test3.groupby(m3).mean()
result3.index = pd.date_range('2014-01-01', periods = 12, freq='MS').strftime('%B')
r3 = result3['총량(kw)'].values.tolist()
r3 = list(map(int, r3))

m4 = df_test4['년월일'].dt.month
result4 = df_test4.groupby(m4).mean()
result4.index = pd.date_range('2015-01-01', periods = 12, freq='MS').strftime('%B')
r4 = result4['총량(kw)'].values.tolist()
r4 = list(map(int, r4))

m5 = df_test5['년월일'].dt.month
result5 = df_test5.groupby(m5).mean()
result5.index = pd.date_range('2016-01-01', periods = 12, freq='MS').strftime('%B')
r5 = result5['총량(kw)'].values.tolist()
r5 = list(map(int, r5))

m6 = df_test6['년월일'].dt.month
result6 = df_test6.groupby(m6).mean()
result6.index = pd.date_range('2017-01-01', periods = 12, freq='MS').strftime('%B')
r6 = result6['총량(kw)'].values.tolist()
r6 = list(map(int, r6))

m7 = df_test7['년월일'].dt.month
result7 = df_test7.groupby(m7).mean()
result7.index = pd.date_range('2018-01-01', periods = 12, freq='MS').strftime('%B')
r7 = result7['총량(kw)'].values.tolist()
r7 = list(map(int, r7))

m8 = df_test8['년월일'].dt.month
result8 = df_test8.groupby(m8).mean()
result8.index = pd.date_range('2019-01-01', periods = 12, freq='MS').strftime('%B')
r8 = result8['총량(kw)'].values.tolist()
r8 = list(map(int, r8))

models = ['13년도 총량(kw)', '14년도 총량(kw)', '15년도 총량(kw)', '16년도 총량(kw)', '17년도 총량(kw)', '18년도 총량(kw)', '19년도 총량(kw)']
xticks = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
data = {'13년도 총량(kw)':r2,'14년도 총량(kw)':r3,'15년도 총량(kw)':r4,'16년도 총량(kw)':r5,'17년도 총량(kw)':r6,'18년도 총량(kw)':r7,'19년도 총량(kw)':r8}
#data = [result2['총량(kw)'], result3['총량(kw)'], result4['총량(kw)'], result5['총량(kw)'], 
#        result6['총량(kw)'], result7['총량(kw)'], result8['총량(kw)']]

plt.rc('font', family='Malgun Gothic')
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
colors = ['orangered', 'orange', 'gold', 'g', 'skyblue', 'navy', 'mediumorchid']
width = 0.1

for i, model in enumerate(models):
    pos = compute_pos(xticks, width, i, models)
    bar = ax.bar(pos, data[model], width=width*0.95, label=model, color=colors[i])
    #present_height(ax, bar) # bar높이 출력

#ax.bar(result2.index, result2['총량(kw)'], alpha=0.5, label = '13년도 총량(kw)')
#ax.bar(result3.index, result3['총량(kw)'], alpha=0.5, label = '14년도 총량(kw)')
#ax.bar(result4.index, result4['총량(kw)'], alpha=0.5, label = '15년도 총량(kw)')
#ax.bar(result5.index, result5['총량(kw)'], alpha=0.5, label = '16년도 총량(kw)')
#ax.bar(result6.index, result6['총량(kw)'], alpha=0.5, label = '17년도 총량(kw)')
#ax.bar(result7.index, result7['총량(kw)'], alpha=0.5, label = '18년도 총량(kw)')
#ax.bar(result8.index, result8['총량(kw)'], alpha=0.5, label = '19년도 총량(kw)')

ax.set_title("연도별 발전량")

ax.set_xticks(range(len(xticks)))
ax.set_xticklabels(xticks, fontsize=10)	
ax.set_xlabel("월", fontsize=14)

ax.set_ylim([0, 1000])
ax.set_yticks([0.5, 0.55, 0.6, 0.65, 0.7, 0.75])
ax.yaxis.set_tick_params(labelsize=10)
ax.set_ylabel("변화량", fontsize=14)

ax.legend(loc='upper right', shadow=True, ncol=1)
ax.set_axisbelow(True)
#ax.yaxis.grid(True, color='gray', linestyle='dashed', linewidth=0.5)
    
plt.tight_layout()
plt.show()
# Out:
# Text(0.5, 1.0, '연도별 발전량')
# ...
# [Text(0, 0, '1월'),
#  Text(0, 0, '2월'),
#  Text(0, 0, '3월'),
#  Text(0, 0, '4월'),
#  Text(0, 0, '5월'),
#  Text(0, 0, '6월'),
#  Text(0, 0, '7월'),
#  Text(0, 0, '8월'),
#  Text(0, 0, '9월'),
#  Text(0, 0, '10월'),
#  Text(0, 0, '11월'),
#  Text(0, 0, '12월')]
# Text(0.5, 0, '월')
# (0, 1000)
# ...
# Text(0, 0.5, '변화량')

# %%
def compute_pos(xticks, width, i, models):
    index = np.arange(len(xticks))
    n = len(models)
    correction = i-0.5*(n-1)
    return index + width*correction

def present_height(ax, bar):
    for rect in bar:
        height = rect.get_height()
        posx = rect.get_x()+rect.get_width()*0.5
        posy = height*1.01
        ax.text(posx, posy, '%.3f' % height, rotation=90, ha='center', va='bottom')

#df = df.fillna(0)

df_test1 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]
df_test2 = df_test1.loc[0:364, :] #13년도
df_test3 = df_test1.loc[365:729, :] #14년도
df_test4 = df_test1.loc[730:1094, :] #15년도
df_test5 = df_test1.loc[1095:1460, :] #16년도
df_test6 = df_test1.loc[1461:1825, :] #17년도
df_test7 = df_test1.loc[1826:2190, :] #18년도
df_test8 = df_test1.loc[2191:2555, :] #19년도
#df_test9 = df_test1.loc[2556:2768, :] #20년도

m2 = df_test2['년월일'].dt.month
result2 = df_test2.groupby(m2).mean()
result2.index = pd.date_range('2013-01-01', periods = 12, freq='MS').strftime('%B')
r2 = result2['총량(kw)'].values.tolist()
r2 = list(map(int, r2))

m3 = df_test3['년월일'].dt.month
result3 = df_test3.groupby(m3).mean()
result3.index = pd.date_range('2014-01-01', periods = 12, freq='MS').strftime('%B')
r3 = result3['총량(kw)'].values.tolist()
r3 = list(map(int, r3))

m4 = df_test4['년월일'].dt.month
result4 = df_test4.groupby(m4).mean()
result4.index = pd.date_range('2015-01-01', periods = 12, freq='MS').strftime('%B')
r4 = result4['총량(kw)'].values.tolist()
r4 = list(map(int, r4))

m5 = df_test5['년월일'].dt.month
result5 = df_test5.groupby(m5).mean()
result5.index = pd.date_range('2016-01-01', periods = 12, freq='MS').strftime('%B')
r5 = result5['총량(kw)'].values.tolist()
r5 = list(map(int, r5))

m6 = df_test6['년월일'].dt.month
result6 = df_test6.groupby(m6).mean()
result6.index = pd.date_range('2017-01-01', periods = 12, freq='MS').strftime('%B')
r6 = result6['총량(kw)'].values.tolist()
r6 = list(map(int, r6))

m7 = df_test7['년월일'].dt.month
result7 = df_test7.groupby(m7).mean()
result7.index = pd.date_range('2018-01-01', periods = 12, freq='MS').strftime('%B')
r7 = result7['총량(kw)'].values.tolist()
r7 = list(map(int, r7))

m8 = df_test8['년월일'].dt.month
result8 = df_test8.groupby(m8).mean()
result8.index = pd.date_range('2019-01-01', periods = 12, freq='MS').strftime('%B')
r8 = result8['총량(kw)'].values.tolist()
r8 = list(map(int, r8))

num = 0
numbers = []
for i in range(0, 12):
    num = r2[i] + r3[i] + r4[i] + r5[i] + r6[i] + r7[i] + r8[i]
    numbers.append(num/7)

models = ['평균 총량(kw)']
xticks = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']
data = {'평균 총량(kw)':numbers}
#data = [result2['총량(kw)'], result3['총량(kw)'], result4['총량(kw)'], result5['총량(kw)'], 
#        result6['총량(kw)'], result7['총량(kw)'], result8['총량(kw)']]

plt.rc('font', family='Malgun Gothic')
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)
colors = ['orange']
width = 0.3

for i, model in enumerate(models):
    pos = compute_pos(xticks, width, i, models)
    bar = ax.bar(pos, data[model], width=width*0.95, label=model, color=colors[i])

ax.set_title("월별 발전량 평균")

ax.set_xticks(range(len(xticks)))
ax.set_xticklabels(xticks, fontsize=10)	
ax.set_xlabel("월", fontsize=14)

ax.set_ylim([0, 1000])
ax.set_yticks([0.5, 0.55, 0.6, 0.65, 0.7, 0.75])
ax.yaxis.set_tick_params(labelsize=10)
ax.set_ylabel("변화량", fontsize=14)

ax.legend(loc='upper right', shadow=True, ncol=1)
ax.set_axisbelow(True)
#ax.yaxis.grid(True, color='gray', linestyle='dashed', linewidth=0.5)
    
plt.tight_layout()
plt.show()
# Out:
# Text(0.5, 1.0, '월별 발전량 평균')
# ...
# [Text(0, 0, '1월'),
#  Text(0, 0, '2월'),
#  Text(0, 0, '3월'),
#  Text(0, 0, '4월'),
#  Text(0, 0, '5월'),
#  Text(0, 0, '6월'),
#  Text(0, 0, '7월'),
#  Text(0, 0, '8월'),
#  Text(0, 0, '9월'),
#  Text(0, 0, '10월'),
#  Text(0, 0, '11월'),
#  Text(0, 0, '12월')]
# Text(0.5, 0, '월')
# (0, 1000)
# ...
# Text(0, 0.5, '변화량')

# %%
df_test2 = df[['년월일', '총량(kw)', '최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']]
df_test2 = df_test2.fillna(0)
#df_test2.head()
#df_test2 = df_test2.loc[0:100, :]

x = [df_test2['최저기온(°C)'], df_test2['최고기온(°C)'], df_test2['일강수량(mm)'], df_test2['평균 풍속(m/s)'], df_test2['평균 상대습도(%)'], df_test2['가조시간(hr)'], df_test2['합계 일사량(MJ/m2)'], df_test2['평균 전운량(1/10)']]
labels = ['최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)', '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)']
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111)

ax.boxplot(x,labels = labels)
plt.show()
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19e560d7ac8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19e54c97148>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19e56215c88>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x19e562a2dc8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x19e56218ac8>,
# ...
#  'means': []}

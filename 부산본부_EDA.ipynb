# %%
import numpy as np
import pandas as pd
from warnings import filterwarnings
filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import seaborn as sns
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./data/부산/발전량+1호기.csv', encoding='utf-8')
df.shape
df.head()
# Out:
# (2883, 10)
#            일시  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  가조시간(hr)  \
# 0  2013-01-01      -2.8       8.0       NaN         3.1        48.5       9.9
# 1  2013-01-02      -5.9       3.6       NaN         4.0        40.9       9.9
# 2  2013-01-03      -7.7      -1.0       NaN         3.9        26.3       9.9
# 3  2013-01-04      -8.1       2.8       NaN         3.7        24.6       9.9
# 4  2013-01-05      -3.8       3.4       NaN         3.4        26.4       9.9
#
#    합계 일사량(MJ/m2)  평균 전운량(1/10)    총량(kw)
# 0           8.99           3.4   988.740
# 1          10.30           1.5  1267.920
# 2          10.77           2.8  1259.316
# 3          11.36           0.3  1386.864
# 4          11.14           0.8  1408.356

# %%
df.tail()
# Out:
#        일시  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  가조시간(hr)  \
# 2878  NaN       NaN       NaN       NaN         NaN         NaN       NaN
# 2879  NaN       NaN       NaN       NaN         NaN         NaN       NaN
# 2880  NaN       NaN       NaN       NaN         NaN         NaN       NaN
# 2881  NaN       NaN       NaN       NaN         NaN         NaN       NaN
# 2882  NaN       NaN       NaN       NaN         NaN         NaN       NaN
#
#       합계 일사량(MJ/m2)  평균 전운량(1/10)  총량(kw)
# 2878            NaN           NaN     NaN
# 2879            NaN           NaN     NaN
# 2880            NaN           NaN     NaN
# 2881            NaN           NaN     NaN
# 2882            NaN           NaN     NaN

# %%
df.describe()
# Out:
#           최저기온(°C)     최고기온(°C)    일강수량(mm)   평균 풍속(m/s)   평균 상대습도(%)  \
# count  2770.000000  2770.000000  899.000000  2769.000000  2770.000000
# mean     12.023430    19.488953   13.320690     3.164030    63.360939
# std       8.700076     7.740305   25.088904     1.150697    18.229006
# min     -10.700000    -4.200000    0.000000     0.300000    17.000000
# 25%       4.700000    13.000000    0.300000     2.400000    49.300000
# 50%      12.800000    20.500000    2.600000     3.000000    64.900000
# 75%      19.300000    25.700000   14.550000     3.700000    77.600000
# max      28.300000    37.300000  264.100000    10.100000    99.900000
#
#           가조시간(hr)  합계 일사량(MJ/m2)  평균 전운량(1/10)       총량(kw)
# count  2770.000000    2697.000000   2770.000000  2770.000000
# mean     12.228773      14.551342      4.793430   676.284368
# std       1.634076       7.232429      3.300806   399.147909
# min       9.800000       0.170000      0.000000     0.000000
# 25%      10.600000       9.550000      1.825000   414.603000
# 50%      12.300000      13.850000      4.600000   662.040000
# 75%      13.800000      20.190000      7.800000   811.260000
# max      14.500000      34.680000     10.000000  1807.740000

# %%
df.isnull().sum()
# Out:
# 일시                113
# 최저기온(°C)          113
# 최고기온(°C)          113
# 일강수량(mm)         1984
# 평균 풍속(m/s)        114
# 평균 상대습도(%)        113
# 가조시간(hr)          113
# 합계 일사량(MJ/m2)     186
# 평균 전운량(1/10)      113
# 총량(kw)            113
# dtype: int64

# %%
df['일강수량(mm)'] = df['일강수량(mm)'].fillna(0)

# %%
df.isnull().sum()
# Out:
# 일시               113
# 최저기온(°C)         113
# 최고기온(°C)         113
# 일강수량(mm)           0
# 평균 풍속(m/s)       114
# 평균 상대습도(%)       113
# 가조시간(hr)         113
# 합계 일사량(MJ/m2)    186
# 평균 전운량(1/10)     113
# 총량(kw)           113
# dtype: int64

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.isnull().sum()
# Out:
# 일시               0
# 최저기온(°C)         0
# 최고기온(°C)         0
# 일강수량(mm)         0
# 평균 풍속(m/s)       0
# 평균 상대습도(%)       0
# 가조시간(hr)         0
# 합계 일사량(MJ/m2)    0
# 평균 전운량(1/10)     0
# 총량(kw)           0
# dtype: int64

# %%
df.shape
df.head()
# Out:
# (2697, 10)
#            일시  최저기온(°C)  최고기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  가조시간(hr)  \
# 0  2013-01-01      -2.8       8.0       0.0         3.1        48.5       9.9
# 1  2013-01-02      -5.9       3.6       0.0         4.0        40.9       9.9
# 2  2013-01-03      -7.7      -1.0       0.0         3.9        26.3       9.9
# 3  2013-01-04      -8.1       2.8       0.0         3.7        24.6       9.9
# 4  2013-01-05      -3.8       3.4       0.0         3.4        26.4       9.9
#
#    합계 일사량(MJ/m2)  평균 전운량(1/10)    총량(kw)
# 0           8.99           3.4   988.740
# 1          10.30           1.5  1267.920
# 2          10.77           2.8  1259.316
# 3          11.36           0.3  1386.864
# 4          11.14           0.8  1408.356

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=df.corr(), annot=True,
fmt='.2f', linewidths=.5, cmap='Blues')

# %%
sns.pairplot(df, x_vars=['최저기온(°C)', '최고기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)',
       '가조시간(hr)', '합계 일사량(MJ/m2)', '평균 전운량(1/10)'],y_vars=['총량(kw)'])

# %% [markdown]
# ### 최소자승법 OLS를 적용한 회귀분석

# %%
from statsmodels.formula.api import ols

# %%
# 필요없는 column을 제거하고 회귀분석 
X = df.drop(['일시', '총량(kw)'], axis='columns')
y = df['총량(kw)']
res = ols('y ~ X', data=df).fit()

# %%
# 필요없는 column을 제거하고 회귀분석 
X = df.drop(['일시', '총량(kw)', '가조시간(hr)', ], axis='columns')
y = df['총량(kw)']
res = ols('y ~ X', data=df).fit()

# %%
X.isnull().sum()
# Out:
# 최저기온(°C)         0
# 최고기온(°C)         0
# 일강수량(mm)         0
# 평균 풍속(m/s)       0
# 평균 상대습도(%)       0
# 가조시간(hr)         0
# 합계 일사량(MJ/m2)    0
# 평균 전운량(1/10)     0
# dtype: int64

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.465
# Method:                 Least Squares   F-statistic:                     294.0
# Date:                Wed, 25 Nov 2020   Prob (F-statistic):               0.00
# Time:                        21:05:43   Log-Likelihood:                -19147.
# No. Observations:                2697   AIC:                         3.831e+04
# Df Residuals:                    2688   BIC:                         3.837e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    502.9279     81.385      6.180      0.000     343.345     662.511
# X[0]         -10.0096      3.714     -2.695      0.007     -17.292      -2.728
# X[1]          13.0849      3.831      3.416      0.001       5.573      20.596
# X[2]          -0.6912      0.422     -1.636      0.102      -1.519       0.137
# X[3]          15.5192      5.137      3.021      0.003       5.446      25.593
# X[4]          -4.6512      0.588     -7.915      0.000      -5.803      -3.499
# X[5]          13.7577      7.474      1.841      0.066      -0.898      28.414
# X[6]          18.0639      1.769     10.211      0.000      14.595      21.533
# X[7]         -29.1887      3.199     -9.123      0.000     -35.462     -22.915
# ==============================================================================
# Omnibus:                      300.382   Durbin-Watson:                   0.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              405.724
# Skew:                           0.930   Prob(JB):                     7.91e-89
# Kurtosis:                       3.384   Cond. No.                     1.05e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
